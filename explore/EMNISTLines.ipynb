# %%
import sys
sys.path.append('..')
from gupt.data.emnist_lines_data_module import EMNISTLinesDataModule

# %%
data = EMNISTLinesDataModule()
data.prepare_data()
data.setup()
# Out:
# ...
#   0%|          | 1785856/561753746 [00:02<11:52, 786414.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\Ramesh\AppData\Local\Temp/ipykernel_13480/4088107801.py in <module>
# ----> 1 data = EMNISTLinesDataModule()
#       2 data.prepare_data()
#       3 data.setup()
#
# c:\Users\Ramesh\Documents\gupt\gupt\data\emnist_lines_data_module.py in __init__(self, args)
#      30         self.limit = 30  # Maximum length of a line
#      31         self.allow_start_end_tokens = True  # Add start and end tokens at the start and end of line respectively
# ---> 32
#      33         self.emnist = EMNISTDataModule()
#      34         self.mapping = self.emnist.mapping
#
# c:\Users\Ramesh\Documents\gupt\gupt\data\emnist_data_module.py in __init__(self, args)
#      42         self.output_dims = (1, )
#      43         if not os.path.exists(EMNIST_MAPPING_FILE_PATH):
# ...
