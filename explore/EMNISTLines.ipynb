# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- -----------
# absl-py                           0.9.0
# aiohttp                           3.7.4.post0
# alabaster                         0.7.12
# altair                            4.1.0
# appdirs                           1.4.4
# arviz                             0.11.2
# asgiref                           3.3.4
# astor                             0.8.1
# astroid                           2.4.1
# astunparse                        1.6.3
# async-timeout                     3.0.1
# atomicwrites                      1.4.0
# attrs                             19.3.0
# Automat                           20.2.0
# autopep8                          1.5.2
# Babel                             2.9.1
# backcall                          0.1.0
# bandit                            1.7.0
# base58                            2.0.1
# beautifulsoup4                    4.9.3
# bleach                            3.1.5
# ...
